# %%
import src.answers

tables = src.answers.getFeathers()
print("Stored Data Tables\n")
for k in sorted(list(tables.keys())):
    print(k)
# Out:
# Stored Data Tables
#
# answers
# answers_blob_anon
# answers_char_anon
# answers_num
# groups
# profilesummary
# qconstraints
# qdtype
# qredundancy
# questionaires
# questions

# %% [markdown]
# ## List of Questionaires

# %%
tables['questionaires'][tables['questionaires'].QuestionaireID.isin([3, 4, 6, 7, 1000000, 1000001, 1000002])]
# Out:
#     QuestionaireID              Description     ViewName  lock
# 2                3            NLR Main form          NLR     0
# 3                4  Interviewer information  Interviewer     0
# 6                6       NRS Form 1994-1999        NLR99     0
# 7                7             Namibia Form      Namibia     0
# 9          1000000      Clinic Questionaire    ND_Clinic     0
# 10         1000001        Shop Questionaire      ND_shop     0
# 11         1000002      School Questionaire    ND_School     0

# %% [markdown]
# ## Search Questions

# %%
searchterm = 'water'
questionaire_id = None
src.answers.quSearch(searchterm, questionaire_id)
# Out:
#                                               Question Datatype  \
# 129                                        Watersource      num
# 200  Where does your hotwater ome from/ other than ...     blob
# 209                                        Watersource      num
# 310  Where does your hotwater ome from/ other than ...     blob
# 561                                    MainWaterSource      num
# 562                              MainWaterSource_Other     char
# 580                                      WaterSourceNo      num
# 634                                     HotwaterSource     char
# 682                                   HotWaterAtClinic      num
# 712                                    MainWaterSource      num
# 713                              MainWaterSource_Other     char
# 796                                    MainWaterSource      num
# 797                              MainWaterSource_other     char
# 851                                   HotwaterAtSchool      num
# 852                                     HotwaterSource     char
# 853                                     HotwaterSource     char
# 854                                   HotwaterAtClinic      num
#
#      QuestionaireID  ColumnNo  Lower     Upper
# 129               3       108    0.0      50.0
# 200               3         9    0.0      50.0
# 209               7       106    0.0      50.0
# 310               7         9    0.0      50.0
# 561         1000000         9    0.0      10.0
# 562         1000000        13    0.0      10.0
# 580               6        27    0.0       1.0
# 634         1000000        33    0.0       1.0
# 682         1000000        57    1.0  100000.0
# 712         1000001         9    0.0      50.0
# 713         1000001        15    0.0      50.0
# 796         1000002        17    0.0      50.0
# 797         1000002        14    0.0      50.0
# 851         1000002        62    0.0       1.0
# 852         1000002        15    1.0      11.0
# 853         1000001        16    1.0       4.0
# 854         1000001        60    0.0       1.0

# %% [markdown]
# ## List of Locations by Year

# %%
year = '2012'
src.answers.getLocations(year)
# Out:
# ['Butterworth',
#  'Fourways Gdns',
#  'Ga-Luka',
#  'Ga-Nkoane',
#  'Hankey',
#  'Matshana',
#  'Matsulu',
#  'Seloshesa',
#  'Vlaklaagte',
#  'Wattville']
